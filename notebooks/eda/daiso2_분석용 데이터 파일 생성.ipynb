# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
# =====================================
# 1. 경로 설정
# =====================================
PROJECT_ROOT = Path(r"G:/Final_proj/Total_clear/데이터")
DATA_DIR = PROJECT_ROOT / "data"
BASE_DIR = DATA_DIR / "ERD_final" / "final_fix"
OUT_DIR = DATA_DIR / "analysis"
OUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"프로젝트 루트: {PROJECT_ROOT}")
print(f"입력 경로: {BASE_DIR}")
print(f"저장 경로: {OUT_DIR}")

# =====================================
# 2. 원천 데이터 로드
# =====================================
brands = pd.read_csv(BASE_DIR / "brands.csv", encoding="cp949")
manufacturer = pd.read_csv(BASE_DIR / "manufacturer.csv", encoding="utf-8-sig")

products_core = pd.read_csv(BASE_DIR / "products_core.csv", encoding="utf-8-sig")
products_category = pd.read_csv(BASE_DIR / "products_category.csv", encoding="utf-8-sig")
products_stats = pd.read_csv(BASE_DIR / "products_stats.csv", encoding="cp949")

functional = pd.read_csv(BASE_DIR / "functional.csv", encoding="utf-8-sig")
sli_results = pd.read_csv(BASE_DIR / "sli_results.csv", encoding="cp949")

reviews_core = pd.read_csv(BASE_DIR / "reviews_core.csv", encoding="cp949")
reviews_text = pd.read_csv(BASE_DIR / "reviews_text.csv", encoding="utf-8-sig")
review_absa = pd.read_csv(BASE_DIR / "review_absa.csv", encoding="cp949")
review_aspects = pd.read_csv(BASE_DIR / "review_aspects.csv", encoding="utf-8-sig")

users_profile = pd.read_csv(BASE_DIR / "users_profile.csv", encoding="cp949")
users_repurchase = pd.read_csv(BASE_DIR / "users_repurchase.csv", encoding="cp949")
user_id_map = pd.read_csv(BASE_DIR / "user_id_map.csv", encoding="cp949")

promotions = pd.read_csv(BASE_DIR / "promotions.csv", encoding="utf-8-sig")

prod_ing = pd.read_csv(BASE_DIR / "products_ingredients.csv", encoding="cp949")
ingredients_dic = pd.read_csv(BASE_DIR / "ingredients_dic.csv", encoding="utf-8-sig")

search_trends = pd.read_csv(BASE_DIR / "search_trends.csv", encoding="cp949")
# Out:
# C:\Users\김미성\AppData\Local\Temp\ipykernel_4764\192856837.py:68: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   s = s.replace({"true": 1, "false": 0, "t": 1, "f": 0, "yes": 1, "no": 0})
# C:\Users\김미성\AppData\Local\Temp\ipykernel_4764\192856837.py:68: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   s = s.replace({"true": 1, "false": 0, "t": 1, "f": 0, "yes": 1, "no": 0})
# ...
